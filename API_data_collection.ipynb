# %%
import numpy as np
import pandas as pd
import requests

# %%
url = "https://active-jobs-db.p.rapidapi.com/active-ats"

query_params = {
    "time_frame": "24h",
    "limit": "10",
    "offset": "0",
    "description_format": "text",
    "title": "Data Engineer",
    "location": "United States"
}

headers = {
    "x-rapidapi-host": "active-jobs-db.p.rapidapi.com",
    "x-rapidapi-key": "36c2fbded6msha93b63dbb9eee84p1e7034jsn41a77dd464ed"  # Your RapidAPI Key
}

response = requests.get(url, headers=headers, params=query_params)
response.json()
# Out:
# [{'id': 2294536084,
#   'date_posted': '2026-08-04T15:37:14',
#   'date_created': '2026-08-04T16:19:34.051266',
#   'title': 'Senior Data Platform Engineer',
#   'organization': 'Gemini',
#   'organization_url': None,
#   'date_valid_through': None,
#   'locations': [{'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressCountry': '',
#      'addressLocality': 'New York, New York'}},
#    {'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressCountry': '',
#      'addressLocality': 'Miami, Florida'}},
#    {'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressCountry': '',
#      'addressLocality': 'Remote (USA)'}}],
#   'locations_alt': ['New York, NY, United States',
#    'Miami, FL, United States',
#    'United States'],
#   'location_type': None,
#   'location_requirements': None,
#   'salary': None,
#   'employment_type': None,
#   'url': 'https://boards.greenhouse.io/embed/job_app?for=gemini&token=8099895&gh_jid=8099895',
#   'source_type': 'ats',
#   'source': 'greenhouse',
#   'source_domain': 'boards.greenhouse.io',
#   'source_slug': 'gemini',
#   'organization_logo': None,
#   'cities_derived': ['Miami', 'New York'],
#   'counties_derived': ['Miami-Dade County'],
#   'regions_derived': ['Florida', 'New York'],
#   'countries_derived': ['United States', 'United States'],
#   'locations_derived': ['Miami, Florida, United States',
#    'New York, New York, United States'],
#   'timezones_derived': ['America/New_York', 'America/New_York'],
#   'lats_derived': [25.7741728, 40.7127281],
#   'lngs_derived': [-80.19362, -74.0060152],
#   'domain_derived': 'gemini.com',
#   'org_linkedin_slug': 'geminitrust',
#   'ai_salary_currency': 'USD',
#   'ai_salary_value': None,
#   'ai_salary_min_value': 126000,
#   'ai_salary_max_value': 180000,
#   'ai_salary_unit_text': 'YEAR',
#   'ai_benefits': ['Competitive starting pay',
#    'Discretionary annual bonus',
#    'New hire equity grant',
#    'Comprehensive health plans',
#    '401k with company matching',
#    'Paid parental leave',
#    'Flexible time off'],
#   'ai_experience_level': '5-10',
#   'ai_work_arrangement': 'Hybrid',
#   'ai_work_arrangement_office_days': None,
#   'ai_remote_location': None,
#   'ai_remote_location_derived': None,
#   'ai_key_skills': ['PostgreSQL',
#    'Amazon Aurora',
#    'Infrastructure as Code',
#    'Terraform',
#    'Python',
#    'Go',
#    'SRE practices',
#    'Automation',
#    'Database scaling',
#    'Observability',
#    'CI/CD',
#    'Kafka',
#    'NoSQL',
#    'Cloud-native environments',
#    'Incident response',
#    'System architecture'],
#   'ai_hiring_manager_name': None,
#   'ai_hiring_manager_email_address': None,
#   'ai_core_responsibilities': 'You will be responsible for the reliability, automation, and operability of the database and datastore fleet using Infrastructure as Code and SRE practices. You will collaborate with engineering teams to build self-service foundations for provisioning, scaling, and monitoring data infrastructure.',
#   'ai_requirements_summary': 'The role requires at least 5 years of experience with deep expertise in managing and scaling relational databases like PostgreSQL or Amazon Aurora. Candidates must demonstrate an SRE mindset with hands-on experience in automation, CI/CD, and cloud-based data platforms.',
#   'ai_working_hours': 40,
#   'ai_employment_type': ['FULL_TIME'],
#   'ai_job_language': 'English',
#   'ai_visa_sponsorship': False,
#   'ai_keywords': ['Data Platform Engineer',
#    'SRE',
#    'PostgreSQL',
#    'Amazon Aurora',
#    'Terraform',
#    'Python',
#    'Go',
#    'Kafka',
#    'NoSQL',
#    'Cloud-native',
#    'AWS',
#    'Redshift',
#    'EMR',
#    'BigQuery',
#    'Databricks',
#    'Infrastructure as Code',
#    'CI/CD',
#    'Observability',
#    'SLOs',
#    'Error budgets',
#    'Database replication',
#    'Failover',
#    'Backup and recovery',
#    'Performance tuning',
#    'Automation',
#    'Web3',
#    'Crypto',
#    'Scalability',
#    'Reliability',
#    'System architecture'],
#   'ai_taxonomies_a': ['Technology',
#    'Engineering',
#    'Data & Analytics',
#    'Software'],
#   'ai_education': None,
#   'description_text': "About the Company\nGemini is a global crypto and Web3 platform founded by Cameron and Tyler Winklevoss in 2014, offering a wide range of simple, reliable, and secure crypto products and services to individuals and institutions in over 70 countries. Our mission is to unlock the next era of financial, creative, and personal freedom by providing trusted access to the decentralized future. We envision a world where crypto reshapes the global financial system, internet, and money to create greater choice, independence, and opportunity for all — bridging traditional finance with the emerging cryptoeconomy in a way that is more open, fair, and secure. As a publicly traded company, Gemini is poised to accelerate this vision with greater scale, reach, and impact.\nThe Department: Platform\nOur Platform organization’s purpose is to enable Gemini to scale effectively and empower our engineering teams to focus on building innovative financial products and experiences for individuals around the world. Platform focuses around building a scalable and secure foundations platform, enabling Engineering to deploy, validate, and operate their services in production, improve resiliency of the service and increase organizational efficiency by reducing operational toil and increase system efficiency through architectural evolution.\nThe Platform team engages directly with our other engineering teams to onboard them onto our platform systems, reviewing and recommending design and architectural decisions, and guiding our engineering teams on how to implement the tooling provided by the larger Platform organization required to ensure systems can scale and react to changing conditions, with continuous improvement loops.\nThe Role: Senior Data Platform Engineer\nAs a Senior Data Platform Engineer, you'll be an SRE for our data infrastructure: responsible for the reliability, automation, and operability of the database and datastore fleet, not just tuning any single engine. You'll work closely with data engineering and product engineering teams to build self-service, automated foundations that let teams provision, scale, and operate their own datastores safely.\nYour role centers on deep relational database expertise (PostgreSQL, Aurora) - internals, replication, failover, backup/recovery, and query performance - paired with the automation and tooling to run that expertise at scale rather than by hand. You'll extend that same automation-first discipline to the other datastores in our fleet - NoSQL/document, columnar, key-value, and streaming systems - so that scaling, failover, and provisioning are repeatable and largely self-service. You'll drive improvements to observability, incident response, and uptime posture through proactive ownership of the platform, and you'll bring SRE practices (SLOs, error budgets, toil reduction, blameless postmortems) to how we run data infrastructure.\nThis role is ideal for someone who thinks in systems and automation first, thrives on cross-team collaboration, and wants to reduce operational toil across a diverse set of database technologies in a fast-paced, cloud-native environment.\nResponsibilities:\nAutomation and Reliability Engineering: Build Infrastructure as Code (IaC), CLI tools, and CI/CD-driven automation that make database provisioning, scaling, failover, and deployment self-service, consistent, and repeatable across environments - this is the core of the role, not a supporting activity.\nDatabase Scaling and Optimization: Serve as the team's depth on relational database systems (e.g., Amazon Aurora, PostgreSQL) - replication topologies, failover, backup/recovery, and query/engine-level performance - ensuring high performance and availability under growing workloads.\nFleet-Wide Infrastructure Design: Extend that operational rigor to the rest of the datastore fleet - document, key-value, and columnar systems - applying the right paradigm to the right workload and building common tooling ...
#  {'id': 2294472560,
#   'date_posted': '2026-08-04T15:24:47',
#   'date_created': '2026-08-04T15:39:56.550987',
#   'title': 'Senior Data Center Facilities Engineer',
#   'organization': 'Oracle',
#   'organization_url': 'https://eeho.fa.us2.oraclecloud.com:443/hcmUI/CandidateExperience/',
#   'date_valid_through': None,
#   'locations': [{'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressLocality': 'Abilene',
#      'addressRegion': 'TX',
#      'addressCountry': 'United States',
#      'postalCode': '',
#      'streetAddress': ''}}],
#   'locations_alt': None,
#   'location_type': '',
#   'location_requirements': None,
#   'salary': None,
#   'employment_type': ['Full time'],
#   'url': 'https://eeho.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_1/job/340895',
#   'source_type': 'ats',
#   'source': 'oraclecloud',
#   'source_domain': 'eeho.fa.us2.oraclecloud.com',
#   'source_slug': None,
#   'organization_logo': None,
#   'cities_derived': ['Abilene'],
#   'counties_derived': ['Taylor County'],
#   'regions_derived': ['Texas'],
#   'countries_derived': ['United States'],
#   'locations_derived': ['Abilene, Texas, United States'],
#   'timezones_derived': ['America/Chicago'],
#   'lats_derived': [32.44645],
#   'lngs_derived': [-99.7475905],
#   'domain_derived': 'oracle.com',
#   'org_linkedin_slug': 'oracle',
#   'ai_salary_currency': None,
#   'ai_salary_value': None,
#   'ai_salary_min_value': None,
#   'ai_salary_max_value': None,
#   'ai_salary_unit_text': None,
#   'ai_benefits': ['Medical',
#    'Life insurance',
#    'Retirement options',
#    'Volunteer programs'],
#   'ai_experience_level': '5-10',
#   'ai_work_arrangement': 'On-site',
#   'ai_work_arrangement_office_days': None,
#   'ai_remote_location': None,
#   'ai_remote_location_derived': None,
#   'ai_key_skills': ['Data center infrastructure',
#    'Preventative maintenance',
#    'Risk management',
#    'Permits to work',
#    'CMMS',
#    'Building systems',
#    'Uninterruptible power supply',
#    'Generators',
#    'Cooling systems',
#    'Building automation',
#    'Fire and life safety systems',
#    'SLA management',
#    'Incident management',
#    'Infrastructure engineering'],
#   'ai_hiring_manager_name': None,
#   'ai_hiring_manager_email_address': None,
#   'ai_core_responsibilities': 'The engineer will track and monitor critical data center infrastructure maintenance to ensure compliance with service level agreements. They will also participate in incident management and support on-site engineering operations.',
#   'ai_requirements_summary': "Candidates must have at least 8 years of experience in data center operations or a bachelor's degree in engineering with 4 years of relevant experience. Proficiency in maintenance management software and risk mitigation is required.",
#   'ai_working_hours': 40,
#   'ai_employment_type': ['FULL_TIME'],
#   'ai_job_language': 'English',
#   'ai_visa_sponsorship': False,
#   'ai_keywords': ['Data Center',
#    'Infrastructure',
#    'Maintenance',
#    'SLA',
#    'Incident Management',
#    'Electrical Engineering',
#    'Industrial Engineering',
#    'Process Engineering',
#    'Preventative Maintenance',
#    'Risk Management',
#    'Permit to Work',
#    'CMMS',
#    'UPS',
#    'Generators',
#    'Cooling',
#    'Building Automation',
#    'Fire Safety',
#    'Life Safety',
#    'Cloud Solutions',
#    'AI'],
#   'ai_taxonomies_a': ['Technology',
#    'Engineering',
#    'Data & Analytics',
#    'Security & Safety'],
#   'ai_education': ['bachelor degree'],
#   'description_text': 'Contributes to tracking and monitoring ongoing Data Center critical\ninfrastructure maintenance and repair for all service lines to pre-defined\nservice level agreements (SLAs). Participates in managing incidents that impact\nData Center infrastructure services and the proactive and timely resolution of\nsuch incidents. Supports on-site data centers operations in relation to the\nengineering infrastructure. Contributes to the creation and upkeep of\nbest-in-class policies and procedures. Participates in training programs for\nnewer members of the team.\n\n\nOnly Oracle brings together the data, infrastructure, applications, and\nexpertise to power everything from industry innovations to life-saving care. And\nwith AI embedded across our products and services, we help customers turn that\npromise into a better future for all. Discover your potential at a company\nleading the way in AI and cloud solutions that impact billions of lives.\n\nTrue innovation starts when everyone is empowered to contribute. That’s why\nwe’re committed to growing a workforce that promotes opportunities for all with\ncompetitive benefits that support our people with flexible medical, life\ninsurance, and retirement options. We also encourage employees to give back to\ntheir communities through our volunteer programs.\n\nWe’re committed to including people with disabilities at all stages of the\nemployment process. If you require accessibility assistance or accommodation for\na disability at any point, let us know by emailing\naccommodation-request_mb@oracle.com [accommodation-request_mb@oracle.com] or by\ncalling 1-888-404-2494 in the United States.\n\nOracle is an Equal Employment Opportunity Employer. All qualified applicants\nwill receive consideration for employment without regard to race, color,\nreligion, sex, national origin, sexual orientation, gender identity, disability\nand protected veterans’ status, or any other characteristic protected by law.\nOracle will consider for employment qualified applicants with arrest and\nconviction records pursuant to applicable law.'},
#  {'id': 2294472561,
#   'date_posted': '2026-08-04T15:24:36',
#   'date_created': '2026-08-04T15:39:56.594832',
#   'title': 'Senior Data Center Facilities Engineer',
#   'organization': 'Oracle',
#   'organization_url': 'https://eeho.fa.us2.oraclecloud.com:443/hcmUI/CandidateExperience/',
#   'date_valid_through': None,
#   'locations': [{'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressLocality': 'Abilene',
#      'addressRegion': 'TX',
#      'addressCountry': 'United States',
#      'postalCode': '',
#      'streetAddress': ''}}],
#   'locations_alt': None,
#   'location_type': '',
#   'location_requirements': None,
#   'salary': None,
#   'employment_type': ['Full time'],
#   'url': 'https://eeho.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_1/job/340970',
#   'source_type': 'ats',
#   'source': 'oraclecloud',
#   'source_domain': 'eeho.fa.us2.oraclecloud.com',
#   'source_slug': None,
#   'organization_logo': None,
#   'cities_derived': ['Abilene'],
#   'counties_derived': ['Taylor County'],
#   'regions_derived': ['Texas'],
#   'countries_derived': ['United States'],
#   'locations_derived': ['Abilene, Texas, United States'],
#   'timezones_derived': ['America/Chicago'],
#   'lats_derived': [32.44645],
#   'lngs_derived': [-99.7475905],
#   'domain_derived': 'oracle.com',
#   'org_linkedin_slug': 'oracle',
#   'ai_salary_currency': None,
#   'ai_salary_value': None,
#   'ai_salary_min_value': None,
#   'ai_salary_max_value': None,
#   'ai_salary_unit_text': None,
#   'ai_benefits': ['Medical',
#    'Life insurance',
#    'Retirement options',
#    'Volunteer programs'],
#   'ai_experience_level': '10+',
#   'ai_work_arrangement': 'On-site',
#   'ai_work_arrangement_office_days': None,
#   'ai_remote_location': None,
#   'ai_remote_location_derived': None,
#   'ai_key_skills': ['Data center infrastructure',
#    'Preventative maintenance',
#    'Risk management',
#    'Permit-to-work processes',
#    'CMMS',
#    'Building systems',
#    'Uninterruptible power supply',
#    'Generators',
#    'Cooling systems',
#    'Building automation',
#    'Fire and life safety systems',
#    'SLA management',
#    'Incident management',
#    'Infrastructure operations'],
#   'ai_hiring_manager_name': None,
#   'ai_hiring_manager_email_address': None,
#   'ai_core_responsibilities': 'The engineer will track and monitor critical data center infrastructure maintenance to ensure compliance with service level agreements. They will also participate in incident management and support on-site engineering operations.',
#   'ai_requirements_summary': "Candidates must have at least 8 years of experience in data center operations or a bachelor's degree in engineering with 4 years of relevant experience. Proficiency in maintenance management software and risk mitigation is required.",
#   'ai_working_hours': 40,
#   'ai_employment_type': ['FULL_TIME'],
#   'ai_job_language': 'English',
#   'ai_visa_sponsorship': False,
#   'ai_keywords': ['Data Center',
#    'Infrastructure',
#    'Maintenance',
#    'SLA',
#    'Incident Management',
#    'Electrical Engineering',
#    'Industrial Engineering',
#    'Process Engineering',
#    'Preventative Maintenance',
#    'Risk Management',
#    'Permit-to-work',
#    'CMMS',
#    'UPS',
#    'Generators',
#    'Cooling',
#    'Building Automation',
#    'Fire Safety',
#    'Life Safety',
#    'Cloud Solutions',
#    'AI'],
#   'ai_taxonomies_a': ['Technology', 'Engineering', 'Data & Analytics'],
#   'ai_education': ['bachelor degree'],
#   'description_text': 'Contributes to tracking and monitoring ongoing Data Center critical\ninfrastructure maintenance and repair for all service lines to pre-defined\nservice level agreements (SLAs). Participates in managing incidents that impact\nData Center infrastructure services and the proactive and timely resolution of\nsuch incidents. Supports on-site data centers operations in relation to the\nengineering infrastructure. Contributes to the creation and upkeep of\nbest-in-class policies and procedures. Participates in training programs for\nnewer members of the team.\n\n\nOnly Oracle brings together the data, infrastructure, applications, and\nexpertise to power everything from industry innovations to life-saving care. And\nwith AI embedded across our products and services, we help customers turn that\npromise into a better future for all. Discover your potential at a company\nleading the way in AI and cloud solutions that impact billions of lives.\n\nTrue innovation starts when everyone is empowered to contribute. That’s why\nwe’re committed to growing a workforce that promotes opportunities for all with\ncompetitive benefits that support our people with flexible medical, life\ninsurance, and retirement options. We also encourage employees to give back to\ntheir communities through our volunteer programs.\n\nWe’re committed to including people with disabilities at all stages of the\nemployment process. If you require accessibility assistance or accommodation for\na disability at any point, let us know by emailing\naccommodation-request_mb@oracle.com [accommodation-request_mb@oracle.com] or by\ncalling 1-888-404-2494 in the United States.\n\nOracle is an Equal Employment Opportunity Employer. All qualified applicants\nwill receive consideration for employment without regard to race, color,\nreligion, sex, national origin, sexual orientation, gender identity, disability\nand protected veterans’ status, or any other characteristic protected by law.\nOracle will consider for employment qualified applicants with arrest and\nconviction records pursuant to applicable law.'},
#  {'id': 2294433539,
#   'date_posted': '2026-08-04T14:30:36',
#   'date_created': '2026-08-04T15:15:55.974075',
#   'title': 'Principal Data Engineer',
#   'organization': 'SMART TECH SKILLS LLC',
#   'organization_url': 'https://smarttechskills.com',
#   'date_valid_through': None,
#   'locations': [{'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressLocality': 'Tallahassee, Florida',
#      'addressRegion': 'FL',
#      'postalCode': '32306',
#      'addressCountry': 'US'}}],
#   'locations_alt': None,
#   'location_type': None,
#   'location_requirements': None,
#   'salary': None,
#   'employment_type': ['FULL_TIME'],
#   'url': 'https://smart-tech-skills.careerplug.com/jobs/3529026/apps/new',
#   'source_type': 'ats',
#   'source': 'careerplug',
#   'source_domain': 'smart-tech-skills.careerplug.com',
#   'source_slug': None,
#   'organization_logo': None,
#   'cities_derived': ['Tallahassee'],
#   'counties_derived': ['Leon County'],
#   'regions_derived': ['Florida'],
#   'countries_derived': ['United States'],
#   'locations_derived': ['Tallahassee, Florida, United States'],
#   'timezones_derived': ['America/New_York'],
#   'lats_derived': [30.442615016666668],
#   'lngs_derived': [-84.29921069523809],
#   'domain_derived': 'smarttechskills.com',
#   'org_linkedin_slug': 'smarttechskills',
#   'ai_salary_currency': None,
#   'ai_salary_value': None,
#   'ai_salary_min_value': None,
#   'ai_salary_max_value': None,
#   'ai_salary_unit_text': None,
#   'ai_benefits': None,
#   'ai_experience_level': '5-10',
#   'ai_work_arrangement': 'On-site',
#   'ai_work_arrangement_office_days': None,
#   'ai_remote_location': None,
#   'ai_remote_location_derived': None,
#   'ai_key_skills': ['Data Architecture',
#    'Data Modeling',
#    'SQL Development',
#    'Database Administration',
#    'ETL/ELT',
#    'Data Governance',
#    'Data Quality Management',
#    'Cloud Data Architecture',
#    'Azure',
#    'AWS',
#    'Oracle',
#    'MySQL',
#    'Performance Tuning',
#    'Artificial Intelligence',
#    'Machine Learning',
#    'Data Migration'],
#   'ai_hiring_manager_name': None,
#   'ai_hiring_manager_email_address': None,
#   'ai_core_responsibilities': 'The Principal Data Engineer will design, develop, and maintain enterprise data architectures and platforms across multiple database environments. This role involves managing data quality, governance, integration, and performance optimization while supporting emerging AI and analytics technologies.',
#   'ai_requirements_summary': 'Candidates must have at least 7 years of experience in data architecture and database administration with expertise in MySQL, Oracle, and SQL development. Strong proficiency in cloud-based data solutions, ETL/ELT processes, and data governance frameworks is required.',
#   'ai_working_hours': 40,
#   'ai_employment_type': ['FULL_TIME'],
#   'ai_job_language': 'English',
#   'ai_visa_sponsorship': False,
#   'ai_keywords': ['Data Architecture',
#    'Data Modeling',
#    'Data Governance',
#    'Data Quality',
#    'ETL',
#    'ELT',
#    'SQL',
#    'MySQL',
#    'Oracle',
#    'Azure SQL',
#    'Database Administration',
#    'Performance Tuning',
#    'Cloud Computing',
#    'Azure',
#    'AWS',
#    'Oracle Cloud',
#    'Data Lakes',
#    'Data Warehousing',
#    'Artificial Intelligence',
#    'Machine Learning',
#    'Generative AI',
#    'LLMs',
#    'RAG',
#    'NoSQL',
#    'Vector Databases',
#    'API Integration',
#    'Data Migration',
#    'Azure DevOps',
#    'GitHub',
#    'Database Security'],
#   'ai_taxonomies_a': ['Data & Analytics',
#    'Technology',
#    'Software',
#    'Engineering'],
#   'ai_education': None,
#   'description_text': 'Location\nOnsite: Tallahassee, FL\n\nExperience Level\nSenior Data Architect / Data Engineer (7+ Years)\n\nPosition Overview\nThe Data Architect / Data Engineer will be responsible for designing, developing, and supporting enterprise data platforms and solutions across multiple database environments. This role focuses on data architecture, data modeling, data quality, data migration, integration, governance, performance optimization, and cloud-based data services. The ideal candidate combines strong database expertise with modern data platform knowledge and an understanding of emerging AI and analytics technologies.\n\nKey Responsibilities\n\nData Architecture & Modeling\nDesign and maintain enterprise data architectures, logical and physical data models.\nDevelop scalable data solutions supporting complex business applications and reporting needs.\nDefine data standards, governance frameworks, and data lifecycle processes.\nTranslate business requirements into effective data architectures and solutions.\nDatabase Development & Administration\nDesign, develop, administer, and optimize databases using MySQL, Oracle, SQL Server, Azure SQL, and related technologies.\nDevelop and optimize SQL queries, stored procedures, views, and database objects.\nPerform schema design, indexing, query optimization, performance tuning, and capacity planning.\nEnsure database security, integrity, reliability, and availability.\nData Quality & Governance\nEstablish and maintain enterprise data quality standards and controls.\nPerform data profiling, validation, cleansing, reconciliation, and integrity checks.\nDevelop data quality monitoring processes and reporting mechanisms.\nSupport enterprise data governance and compliance initiatives.\nData Integration & Migration\nDesign and support ETL/ELT processes and enterprise data integration solutions.\nDevelop and maintain APIs, middleware integrations, and data exchange services.\nSupport data migration, conversion, and synchronization efforts across platforms.\nIntegrate data between enterprise applications, databases, and cloud services.\nCloud & Modern Data Platforms\nDesign and support cloud-based data solutions using: \nMicrosoft Azure\nAWS\nOracle Cloud\nSupport data lakes, data warehouses, cloud databases, and modern analytics environments.\nOptimize cloud-based data architectures for scalability, performance, and cost efficiency.\nSecurity, Compliance & Risk Management\nImplement database security controls, access management, and governance policies.\nEnsure compliance with cybersecurity, privacy, and regulatory requirements.\nProtect enterprise data through monitoring, auditing, and security best practices.\nAI & Emerging Technologies\nSupport initiatives involving: \nArtificial Intelligence (AI)\nMachine Learning (ML)\nGenerative AI\nLarge Language Models (LLMs)\nRetrieval-Augmented Generation (RAG)\nIntelligent Document Processing\nVector Databases\nNoSQL Databases\nEmbeddings and AI-ready Data Architectures\nEvaluate opportunities to modernize enterprise data platforms using emerging technologies.\nRequired Qualifications\nStrong experience designing and supporting enterprise data solutions.\nExperience with data architecture, data modeling, and enterprise data management.\nExtensive experience with: \nMySQL\nOracle\nSQL Development\nDatabase Administration\nPerformance Tuning\nExperience implementing data quality management and governance practices.\nExperience with ETL/ELT, data migration, and integration projects.\nExperience developing APIs and supporting enterprise integrations.\nExperience with Azure DevOps, GitHub, Oracle SQL Developer, or comparable tools.\nKnowledge of database security, access controls, and compliance requirements.\nStrong written and verbal communication skills.\nPreferred Qualifications\nExperience with Microsoft SQL Server and Azure SQL.\nExperience supporting cloud-native data architectures.\nExperience with AWS, Azure, and Oracle Clo ...
#  {'id': 2294393006,
#   'date_posted': '2026-08-04T14:17:02',
#   'date_created': '2026-08-04T14:51:49.39792',
#   'title': 'Data Engineer',
#   'organization': 'Software Finder',
#   'organization_url': 'https://softwarefinder.na.teamtailor.com',
#   'date_valid_through': None,
#   'locations': [{'@type': 'Place',
#     'address': {'streetAddress': '34s Main Blvd Gulberg',
#      'addressLocality': 'Lahore',
#      'postalCode': '54920',
#      'addressCountry': 'PK',
#      'addressRegion': None,
#      '@type': 'PostalAddress'}}],
#   'locations_alt': None,
#   'location_type': None,
#   'location_requirements': None,
#   'salary': None,
#   'employment_type': ['FULL_TIME'],
#   'url': 'https://softwarefinder.na.teamtailor.com/jobs/676581-data-engineer',
#   'source_type': 'ats',
#   'source': 'teamtailor',
#   'source_domain': 'softwarefinder.na.teamtailor.com',
#   'source_slug': None,
#   'organization_logo': 'https://images.teamtailor-cdn.com/images/s3/teamtailor-na-maroon/logotype-v3/image_uploads/f81b8edf-e341-4c56-949e-8d4a33d794d6/original.webp',
#   'cities_derived': ['201 District'],
#   'counties_derived': ['Orange County'],
#   'regions_derived': ['Virginia'],
#   'countries_derived': ['United States'],
#   'locations_derived': ['201 District, Virginia, United States'],
#   'timezones_derived': ['America/New_York'],
#   'lats_derived': [38.1987457],
#   'lngs_derived': [-77.9694418],
#   'domain_derived': 'softwarefinder.com',
#   'org_linkedin_slug': 'softwarefinder-us',
#   'ai_salary_currency': None,
#   'ai_salary_value': None,
#   'ai_salary_min_value': None,
#   'ai_salary_max_value': None,
#   'ai_salary_unit_text': None,
#   'ai_benefits': None,
#   'ai_experience_level': '2-5',
#   'ai_work_arrangement': 'On-site',
#   'ai_work_arrangement_office_days': None,
#   'ai_remote_location': None,
#   'ai_remote_location_derived': None,
#   'ai_key_skills': ['AWS',
#    'Python',
#    'SQL',
#    'Apache Airflow',
#    'Data Engineering',
#    'ETL/ELT',
#    'Data Modeling',
#    'Redshift',
#    'S3',
#    'Glue',
#    'Lambda',
#    'Athena',
#    'Git',
#    'Data Warehousing',
#    'Business Intelligence',
#    'CI/CD'],
#   'ai_hiring_manager_name': None,
#   'ai_hiring_manager_email_address': None,
#   'ai_core_responsibilities': 'Design, build, and maintain scalable ETL/ELT pipelines on AWS to support business intelligence and strategic decision-making. Collaborate with the BI team to ensure data accuracy and optimize data models for performance and reliability.',
#   'ai_requirements_summary': "Requires a bachelor's degree in a technical field and 2–3 years of professional experience in data or backend engineering. Candidates must possess strong SQL and Python skills, along with hands-on experience in AWS data services and workflow orchestration.",
#   'ai_working_hours': 40,
#   'ai_employment_type': ['FULL_TIME'],
#   'ai_job_language': 'English',
#   'ai_visa_sponsorship': False,
#   'ai_keywords': ['Data Engineering',
#    'AWS',
#    'ETL',
#    'ELT',
#    'SQL',
#    'Python',
#    'Apache Airflow',
#    'AWS Step Functions',
#    'S3',
#    'Glue',
#    'Redshift',
#    'Lambda',
#    'Athena',
#    'EventBridge',
#    'Data Modeling',
#    'Normalization',
#    'Dimensional Modeling',
#    'Git',
#    'BI',
#    'Data Warehouse',
#    'Dbt',
#    'Terraform',
#    'CI/CD',
#    'GitHub Actions',
#    'AWS CodePipeline',
#    'Observability',
#    'Claude Code',
#    'Data Governance',
#    'Backend Engineering',
#    'Automation'],
#   'ai_taxonomies_a': ['Technology',
#    'Data & Analytics',
#    'Software',
#    'Engineering'],
#   'ai_education': ['bachelor degree'],
#   'description_text': 'Job Overview\nSoftware Finder is seeking skilled and motivated Data Engineers to join our growing Data Engineering team. This is a generalist AWS-focused role where you will own data pipelines end-to-end—from ingestion and transformation to delivering reliable data that supports business intelligence and strategic decision-making.\nThe pipelines and data products you build will directly support revenue-driving systems and analytics, extending beyond internal reporting. This role also offers opportunities to expand into broader software engineering responsibilities as your expertise and the team’s needs evolve.\nKey Responsibilities\nDesign, build, deploy, and maintain scalable ETL/ELT pipelines on AWS.\nIngest and transform data from multiple source systems into the organization’s data warehouse.\nWrite, optimize, and maintain complex SQL queries for data transformation, modelling, and analytics.\nDevelop reliable data models that support BI dashboards, reporting, and business analysis.\nOrchestrate workflows using Apache Airflow or AWS Step Functions.\nMonitor pipeline health, investigate failures, and implement long-term solutions to recurring issues.\nCollaborate closely with the BI team to improve data accuracy, consistency, and trustworthiness.\nEstablish feedback loops between Data Engineering and BI to address data-quality gaps.\nImprove pipeline reliability, performance, observability, and cost efficiency.\nUse AI-assisted development tools, such as Claude Code, to accelerate development and iteration.\nParticipate in code reviews and follow established engineering standards.\nMaintain technical documentation for pipelines, data models, and workflows.\nGradually contribute to broader backend and software engineering initiatives.\nPerform additional data engineering and technology-related tasks as assigned.\nRequirements\nBachelor’s degree in Computer Science, Software Engineering, Data Science, Information Technology, or a related discipline.\n2–3 years of professional experience in data engineering or a backend/software engineering role involving significant data work.\nStrong SQL skills, including experience writing and optimizing complex queries.\nProficiency in Python for building data pipelines and automation workflows.\nHands-on experience with AWS data services such as S3, Glue, Redshift, Lambda, Athena, and EventBridge.\nPractical experience with Apache Airflow or AWS Step Functions for workflow orchestration.\nStrong understanding of data-modelling fundamentals, including normalization and dimensional modelling.\nFamiliarity with Git and collaborative software-development workflows.\nAbility to troubleshoot data-quality issues, pipeline failures, and performance bottlenecks.\nStrong analytical, problem-solving, and cross-functional communication skills.\nWillingness to work onsite in Lahore from 11:00 AM to 8:00 PM PKT.\nPreferred Skills\nExperience with dbt for SQL-based data transformation.\nFamiliarity with Terraform or other infrastructure-as-code tools.\nExperience with CI/CD pipelines using GitHub Actions, AWS CodePipeline, or similar tools.\nExperience with data monitoring, observability, and pipeline-cost optimization.\nFamiliarity with AI coding assistants such as Claude Code.\nUnderstanding of data governance, validation, and quality-control practices.\nInterest in growing into broader backend or software engineering responsibilities.\n\nLocation: Lahore, Onsite\nWorking Hours: 11:00 AM–8:00 PM PKT\nNumber of Openings: 2'},
#  {'id': 2294404752,
#   'date_posted': '2026-08-04T14:16:10',
#   'date_created': '2026-08-04T15:00:46.92597',
#   'title': 'AI Data Engineer',
#   'organization': 'SAIC',
#   'organization_url': 'https://eihu.fa.us8.oraclecloud.com:443/hcmUI/CandidateExperience/',
#   'date_valid_through': None,
#   'locations': [{'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressLocality': 'Fort Belvoir',
#      'addressRegion': 'VA',
#      'addressCountry': 'US',
#      'postalCode': '22060',
#      'streetAddress': 'Customer Site,  '}}],
#   'locations_alt': None,
#   'location_type': '',
#   'location_requirements': None,
#   'salary': None,
#   'employment_type': None,
#   'url': 'https://eihu.fa.us8.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX/job/2615231',
#   'source_type': 'ats',
#   'source': 'oraclecloud',
#   'source_domain': 'eihu.fa.us8.oraclecloud.com',
#   'source_slug': None,
#   'organization_logo': None,
#   'cities_derived': ['Fort Belvoir'],
#   'counties_derived': ['Fairfax County'],
#   'regions_derived': ['Virginia'],
#   'countries_derived': ['United States'],
#   'locations_derived': ['Fort Belvoir, Virginia, United States'],
#   'timezones_derived': ['America/New_York'],
#   'lats_derived': [38.7104757],
#   'lngs_derived': [-77.1471487],
#   'domain_derived': 'saic.com',
#   'org_linkedin_slug': 'saicinc',
#   'ai_salary_currency': None,
#   'ai_salary_value': None,
#   'ai_salary_min_value': None,
#   'ai_salary_max_value': None,
#   'ai_salary_unit_text': None,
#   'ai_benefits': None,
#   'ai_experience_level': '5-10',
#   'ai_work_arrangement': 'On-site',
#   'ai_work_arrangement_office_days': None,
#   'ai_remote_location': None,
#   'ai_remote_location_derived': None,
#   'ai_key_skills': ['Data Engineering',
#    'Palantir Foundry',
#    'Python',
#    'SQL',
#    'TypeScript',
#    'ETL',
#    'Data Architecture',
#    'Machine Learning',
#    'Large Language Models',
#    'NLP',
#    'Data Governance',
#    'Systems Engineering',
#    'Database Management',
#    'Conversational AI',
#    'Object-oriented Development'],
#   'ai_hiring_manager_name': None,
#   'ai_hiring_manager_email_address': None,
#   'ai_core_responsibilities': 'The AI Data Engineer will design, develop, and maintain scalable data pipelines and architectures to support AI/ML workloads for the Army Intelligence & Security Enterprise. They will collaborate with cross-functional teams to optimize data workflows and ensure data quality, security, and operational integration.',
#   'ai_requirements_summary': "Candidates must have at least a bachelor's degree and five years of relevant experience in systems or data engineering. Proficiency in Palantir Foundry, Python, SQL, and TypeScript is required, along with an active TS/SCI security clearance.",
#   'ai_working_hours': 40,
#   'ai_employment_type': ['FULL_TIME'],
#   'ai_job_language': 'English',
#   'ai_visa_sponsorship': False,
#   'ai_keywords': ['AI Data Engineer',
#    'SAIC',
#    'Fort Belvoir',
#    'Data Pipelines',
#    'AI/ML',
#    'Army Intelligence',
#    'Palantir Foundry',
#    'Ontologies',
#    'Object Types',
#    'AIP',
#    'ETL',
#    'Python',
#    'SQL',
#    'TypeScript',
#    'Large Language Models',
#    'NLP',
#    'Data Governance',
#    'Security Protocols',
#    'TS/SCI Clearance',
#    'Systems Engineering',
#    'Data Architecture',
#    'Object-oriented Development',
#    'Conversational AI',
#    'Mission Integrator',
#    'Defense'],
#   'ai_taxonomies_a': ['Technology',
#    'Data & Analytics',
#    'Software',
#    'Government & Public Sector',
#    'Security & Safety'],
#   'ai_education': ['bachelor degree', 'postgraduate degree'],
#   'description_text': 'SAIC is seeking an AI Data Engineer to join our team at Fort Belvoir, Virginia.\n\nThe AI Data Engineer will design, develop, and maintain data pipelines and\narchitectures to support AI/ML workloads for the Army Intelligence & Security\nEnterprise (AISE). This role ensures data availability, quality, security, and\noperational integration to enable advanced analytics and decision-making. The AI\nData Engineer will collaborate with cross-functional teams, optimize data\nworkflows, and contribute to intelligence solutions.\n\nKey Responsibilities:\n\n * Translate business requirements into logical data models to support entity\n   relationships and data flows.\n * Design and implement scalable data pipelines for AI and machine learning\n   workloads.\n * Develop and maintain data architectures to ensure data quality, availability,\n   and security.\n * Collaborate with internal teams and external stakeholders to meet AI/ML data\n   requirements.\n * Optimize data workflows for real-time analytics and decision-making.\n * Ensure adherence to data governance policies and security protocols.\n * Stay current on data engineering, AI, and machine learning advancements.\n * Support the operational deployment and integration of AI/ML solutions to\n   enhance intelligence capabilities.\n * Analyze complex data challenges and deliver practical, innovative technical\n   solutions aligned with organizational goals.\n * Engage frequently with internal and external stakeholders to resolve\n   technical issues and deliver impactful solutions.\n * Contribute to the successful delivery of programs and projects.\n\n\nSAIC® [http://www.saic.com/]\xa0is a premier mission integrator focused on\nadvancing the power of technology and innovation to serve and protect our world.\nOur robust portfolio of offerings across the defense, space, intelligence, and\ncivilian markets includes secure high-end solutions in mission IT, enterprise\nIT, engineering services, and professional services. We integrate emerging\ntechnology, rapidly and securely, into mission critical operations that\nmodernize and enable critical national imperatives.\n\nWe are approximately 23,000 strong; driven by mission, united by purpose, and\ninspired by opportunities. SAIC is an Equal Opportunity Employer. Headquartered\nin Reston, Virginia, SAIC has annual revenues of approximately $7.3 billion. For\nmore information, visit\xa0saic.com [http://www.saic.com/]. For ongoing news,\nplease visit our\xa0newsroom [http://www.saic.com/who-we-are/newsroom/].'},
#  {'id': 2294344847,
#   'date_posted': '2026-08-04T14:02:18.877',
#   'date_created': '2026-08-04T14:05:55.654802',
#   'title': 'Senior Mechanical Commissioning Engineer (Data Center)',
#   'organization': 'Veolia Environnement SA',
#   'organization_url': None,
#   'date_valid_through': None,
#   'locations': [{'address': {'streetAddress': '1301 Bellwood Road',
#      'addressLocality': 'Richmond',
#      'addressRegion': 'Virginia',
#      'postalCode': '23237',
#      'addressCountry': 'United States'}}],
#   'locations_alt': ['1301 Bellwood Rd, Richmond, VA 23237, USA'],
#   'location_type': None,
#   'location_requirements': None,
#   'salary': None,
#   'employment_type': ['Full-time'],
#   'url': 'https://jobs.smartrecruiters.com/VeoliaEnvironnementSA/744000141505764-senior-mechanical-commissioning-engineer-data-center-',
#   'source_type': 'ats',
#   'source': 'smartrecruiters',
#   'source_domain': 'jobs.smartrecruiters.com',
#   'source_slug': None,
#   'organization_logo': None,
#   'cities_derived': ['Bellwood'],
#   'counties_derived': ['Chesterfield County'],
#   'regions_derived': ['Virginia'],
#   'countries_derived': ['United States'],
#   'locations_derived': ['Bellwood, Virginia, United States'],
#   'timezones_derived': ['America/New_York'],
#   'lats_derived': [37.4162554],
#   'lngs_derived': [-77.4118604],
#   'domain_derived': 'veolia.com',
#   'org_linkedin_slug': 'veolia-france',
#   'ai_salary_currency': 'USD',
#   'ai_salary_value': None,
#   'ai_salary_min_value': 120000,
#   'ai_salary_max_value': 130000,
#   'ai_salary_unit_text': 'YEAR',
#   'ai_benefits': ['Paid time off',
#    'Health insurance',
#    'Dental insurance',
#    'Vision insurance',
#    'Life insurance',
#    'Savings accounts',
#    'Tuition reimbursement',
#    'Paid volunteering',
#    '401(k) plan'],
#   'ai_experience_level': '5-10',
#   'ai_work_arrangement': 'On-site',
#   'ai_work_arrangement_office_days': None,
#   'ai_remote_location': None,
#   'ai_remote_location_derived': None,
#   'ai_key_skills': ['Mechanical commissioning',
#    'Data center systems',
#    'Building mechanical systems',
#    'Troubleshooting',
#    'Project documentation',
#    'Functional testing',
#    'Technical reporting',
#    'BMS',
#    'EPMS',
#    'DDC controls',
#    'PLC controls',
#    'Project management',
#    'Team leadership',
#    'Instrumentation',
#    'Safety compliance'],
#   'ai_hiring_manager_name': None,
#   'ai_hiring_manager_email_address': None,
#   'ai_core_responsibilities': 'The Senior Mechanical Commissioning Engineer will plan and execute the commissioning of mechanical systems in data center environments, including testing, troubleshooting, and documentation. They will also provide technical guidance to project teams and assist in the coordination of field activities and schedules.',
#   'ai_requirements_summary': 'Candidates must possess a BSc/MSc in Mechanical Engineering with at least 5 years of mission-critical experience, or 7+ years of relevant commissioning experience. Strong technical competency in building mechanical systems and the ability to travel extensively are required.',
#   'ai_working_hours': 40,
#   'ai_employment_type': ['FULL_TIME'],
#   'ai_job_language': 'English',
#   'ai_visa_sponsorship': False,
#   'ai_keywords': ['Mechanical Engineering',
#    'Commissioning',
#    'Data Center',
#    'Mission Critical',
#    'HVAC',
#    'Chillers',
#    'Cooling Towers',
#    'Generators',
#    'BMS',
#    'EPMS',
#    'ASHRAE',
#    'BCxA',
#    'DDC',
#    'PLC',
#    'Fire Suppression',
#    'Testing',
#    'Troubleshooting',
#    'Project Management',
#    'Field Engineering',
#    'Instrumentation',
#    'Hydronic Systems',
#    'Air Handling Units',
#    'Fuel Systems',
#    'Gas Turbines',
#    'Steam Turbines',
#    'Variable Frequency Drive',
#    'Leak Detection',
#    'VESDA',
#    'Safety',
#    'Reporting'],
#   'ai_taxonomies_a': ['Engineering',
#    'Construction',
#    'Energy',
#    'Environmental & Sustainability',
#    'Management & Leadership'],
#   'ai_education': ['bachelor degree', 'postgraduate degree'],
#   'description_text': 'Company Description\nVeolia in North America is the top-ranked environmental company in the United States for three consecutive years, and the country’s largest private water operator and technology provider as well as hazardous waste and pollution treatment leader. It offers a full spectrum of water, waste, and energy management services, including water and wastewater treatment, commercial and hazardous waste collection and disposal, energy consulting and resource recovery. Veolia helps commercial, industrial, healthcare, higher education and municipality customers throughout North America. Headquartered in Boston, Veolia has more than 10,000 employees working at more than 350 locations across North America.\nJob Description\nPosition Purpose:\nSenior Project Engineer – Performs & plans commissioning of mechanical systems. Must be a self-motivated & energetic professional. Must have understanding of building mechanical systems design, construction & operation. Must have experience with commissioning process of mechanical systems ranging in size, rating and complexity. The ideal candidate shall possess theoretical and practical knowledge in the commissioning, testing and troubleshooting of mechanical systems and related controls. Candidate will be responsible for reviewing project information; executing daily field activities; maintaining project documentation; assisting the Project Manager with schedule and planning of resources, and providing guidance to Project Engineers. May perform as team lead on small to medium sized projects. Will be expected to assess and test at a high technical level. This role requires the candidate to have technical competency, organizational skills, good communication skills, and to work well in a team environment where leadership is necessary.\nPrimary Duties/Responsibilities:\nList essential job functions that comprise the job; describe in terms of actions (verbs) and desired outcomes in order of most important first:\nCommission mechanical, plumbing & fire alarm and suppression equipment and related controls, primarily in data center environments.\nReview system designs for compliance with client facility goals.\nPrepare plans and procedures for execution of the commissioning process.\nConduct commissioning activities from the design phase through the occupation phase, in accordance with client requirements and industry commissioning process best practices.\nAttend factory testing of equipment and document procedures and results.\nConduct functional testing of equipment.\nPerform analysis of test results using instrumentation and prepare reports.\nFully document all field procedures including results, issues and observations either via company provided templates or online applications.\nReport on system performance and make technical recommendations on issues.\nWork with the Project Manager and project teams to coordinate and execute field activities.\nPrepare and provide input on commissioning project documentation and schedules.\nDraft comprehensive test procedures for a variety of equipment and systems.\nAttend relevant project coordination and schedule meetings as necessary.\nMay be required to lead commissioning meetings or speak on technical topics.\nAssist with submitting and maintaining daily commissioning reports.\nTrain and guide both Associate Project Engineers and Project Engineers on roles & responsibilities.\nRespond to project team and client inquiries in a professional and timely manner.\nComply with company, client, and project safety requirements.\nBe knowledgeable with Mechanical, Plumbing & FLS building systems & equipment, including, but not limited to:\nAir Cooled Chiller\nWater Cooled Chiller\nCooling Tower\nDirect Evaporative Cooling System\nAir Handling Unit\nComputer Room Air Conditioning Unit\nProcess Water Plants\nBoilers\nFuel Systems\nBackup generators\nGas turbines\nReciprocating engines\nSteam turbines\nSelective catalytic reduction syste ...
#  {'id': 2294326420,
#   'date_posted': '2026-08-04T13:07:49',
#   'date_created': '2026-08-04T13:54:51.457293',
#   'title': 'Senior Salesforce Data Engineer',
#   'organization': 'Cherokee Federal',
#   'organization_url': 'https://ibtcjb.fa.ocs.oraclecloud.com:443/hcmUI/CandidateExperience/',
#   'date_valid_through': None,
#   'locations': [{'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressLocality': 'Washington',
#      'addressRegion': 'DC',
# ...
#  {'id': 2294228556,
#   'date_posted': '2026-08-04T12:34:56',
#   'date_created': '2026-08-04T12:35:02.981823',
#   'title': 'Senior Data Architect / Data Engineer',
#   'organization': 'Jahnel Group',
#   'organization_url': None,
#   'date_valid_through': None,
#   'locations': [{'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressCountry': '',
#      'addressLocality': 'Schenectady, New York, United States, Remote'}}],
#   'locations_alt': ['Schenectady, NY, United States'],
#   'location_type': None,
#   'location_requirements': None,
#   'salary': None,
#   'employment_type': None,
#   'url': 'https://www.jahnelgroup.com/apply.html?gh_jid=5202903007',
#   'source_type': 'ats',
#   'source': 'greenhouse',
#   'source_domain': 'www.jahnelgroup.com',
#   'source_slug': 'jahnelgroup',
#   'organization_logo': None,
#   'cities_derived': ['Schenectady'],
#   'counties_derived': ['Schenectady County'],
#   'regions_derived': ['New York'],
#   'countries_derived': ['United States'],
#   'locations_derived': ['Schenectady, New York, United States'],
#   'timezones_derived': ['America/New_York'],
#   'lats_derived': [42.8142432],
#   'lngs_derived': [-73.9395687],
#   'domain_derived': 'jahnelgroup.com',
#   'org_linkedin_slug': 'jahnelgroup',
#   'ai_salary_currency': None,
#   'ai_salary_value': None,
#   'ai_salary_min_value': None,
#   'ai_salary_max_value': None,
#   'ai_salary_unit_text': None,
#   'ai_benefits': None,
#   'ai_experience_level': '10+',
#   'ai_work_arrangement': 'Remote OK',
#   'ai_work_arrangement_office_days': None,
#   'ai_remote_location': ['Schenectady, New York, United States'],
#   'ai_remote_location_derived': ['Schenectady, New York, United States'],
#   'ai_key_skills': ['Data Architecture',
#    'Data Engineering',
#    'Data Modeling',
#    'SQL',
#    'Google Cloud Platform',
#    'Data Migration',
#    'Data Transformation',
#    'Canonical Data Modeling',
#    'Relational Data Modeling',
#    'Git',
#    'GitLab',
#    'Mentorship',
#    'Technical Leadership',
#    'System Integration',
#    'Data Quality'],
#   'ai_hiring_manager_name': None,
#   'ai_hiring_manager_email_address': None,
#   'ai_core_responsibilities': 'The role involves designing and leading a complex data architecture initiative to migrate and unify data across 11 legacy systems. You will be responsible for developing data models, writing migration scripts, and providing technical mentorship to the data team.',
#   'ai_requirements_summary': "Candidates must have 8+ years of experience in data engineering or architecture with strong expertise in relational modeling and cloud-based environments. A bachelor's degree in a related field is preferred, and candidates must be legally authorized to work in the U.S.",
#   'ai_working_hours': 40,
#   'ai_employment_type': ['FULL_TIME'],
#   'ai_job_language': 'English',
#   'ai_visa_sponsorship': False,
#   'ai_keywords': ['Data Architect',
#    'Data Engineer',
#    'Software Creators',
#    'Data Transformation',
#    'Legacy Systems',
#    'Data Modeling',
#    'Canonical Model',
#    'Data Migration',
#    'Data Quality',
#    'SQL',
#    'GCP',
#    'Cloud-based Data Environments',
#    'Git',
#    'GitLab',
#    'Mentorship',
#    'Enterprise Environments',
#    'Normalization',
#    'Schemas',
#    'Data Structures',
#    'Technical Guidance',
#    'Scalability',
#    'Maintainability',
#    'INC 5000'],
#   'ai_taxonomies_a': ['Data & Analytics',
#    'Software',
#    'Technology',
#    'Engineering',
#    'Consulting'],
#   'ai_education': ['bachelor degree'],
#   'description_text': "Jahnel Group’s mission is to provide the absolute best environment for software creators to pursue their passion by connecting them with great clients doing meaningful work.\nWe get to build some of the most complex and compelling applications for our clients located across the country. We’re a fast-growing INC 5000 recognized company, yet we still work as a very close-knit team (100+ employees). We’re growing like crazy, and if you’re looking for the next place to call home, hit us up for a beer or coffee.\nWho We’re Looking For\nWe're looking for a Senior Data Architect / Data Engineer to help lead a complex data transformation and migration initiative. This is a highly senior, architecture-heavy role focused on making sense of data across approximately 11 legacy systems and helping shape a unified or semi-unified data model.\nThe ideal candidate has strong data modeling judgment, can quickly understand messy and inconsistent source data, and knows when a canonical model makes sense versus when it will create unnecessary complexity. You’ll also be expected to stay hands-on, writing and shipping scripts for migration and transformation while providing technical guidance to less experienced data team members.\nInstead of the typical job description, here's a breakdown of the tasks and qualities we're looking for in our next team member:\nPrimary Responsibilities\nDesign and guide data architecture for a complex transformation and migration initiative spanning approximately 11 legacy systems.\nAnalyze highly varied source data, potentially including roughly 400 form variants and source structures.\nDevelop unified or semi-unified data models that balance consistency, flexibility, and long-term maintainability.\nMake thoughtful architectural decisions around canonical data models, mappings, transformations, and source-specific variations.\nWrite and ship scripts quickly to support data migration, transformation, validation, and cleanup.\nIdentify data quality issues, inconsistencies, and structural gaps across legacy systems and develop practical solutions.\nCollaborate with technical and business stakeholders to understand existing data structures and future-state requirements.\nProvide technical guidance and mentorship to junior and mid-level data team members.\nHelp establish patterns and best practices that reduce rework and support future data initiatives.\nSkills and Qualifications\n8+ years of experience in data engineering, data architecture, or a closely related field.\nStrong experience designing data architecture and data models for complex enterprise environments.\nProven experience working with legacy systems and large-scale data transformation or migration efforts.\nStrong understanding of relational data modeling, data structures, schemas, mappings, and normalization.\nDemonstrated ability to determine when a canonical data model is appropriate and when a more flexible approach is needed.\nStrong SQL skills and the ability to quickly write scripts for data transformation and migration.\nExperience with Google Cloud Platform (GCP) and cloud-based data environments.\nComfortable working hands-on while also making high-level architectural decisions.\nStrong problem-solving skills and the ability to bring structure to ambiguous or messy data environments.\nExperience mentoring or advising other data engineers and helping less experienced team members grow.\nExperience with Git-based development workflows; GitLab experience is a plus.\nExcellent communication skills and the ability to explain complex technical concepts to both technical and non-technical stakeholders.\nBachelor’s degree in Computer Science, Engineering, Information Systems, or a related field is preferred.\nCandidates must be legally authorized to work in the U.S. without current or future sponsorship.\nWhat Makes Someone Successful in This Role\nThinks like an architect but isn't afraid to write the code.\nEnjoys solving messy,  ...
#  {'id': 2294239758,
#   'date_posted': '2026-08-04T07:13:26',
#   'date_created': '2026-08-04T12:44:50.175544',
#   'title': 'Senior Data Engineer',
#   'organization': 'UnitedHealth Group',
#   'organization_url': None,
#   'date_valid_through': None,
#   'locations': [{'@type': 'Place',
#     'address': {'@type': 'PostalAddress',
#      'addressCountry': '',
#      'addressLocality': 'US, NC, Raleigh'}}],
#   'locations_alt': ['Raleigh, NC, United States'],
#   'location_type': None,
#   'location_requirements': None,
#   'salary': None,
#   'employment_type': ['Full-time'],
#   'url': 'https://uhg.taleo.net/careersection/10000/jobdetail.ftl?job=2366631&lang=en',
#   'source_type': 'ats',
#   'source': 'taleo',
#   'source_domain': 'uhg.taleo.net',
#   'source_slug': None,
#   'organization_logo': None,
#   'cities_derived': ['Raleigh'],
#   'counties_derived': ['Wake County'],
#   'regions_derived': ['North Carolina'],
#   'countries_derived': ['United States'],
#   'locations_derived': ['Raleigh, North Carolina, United States'],
#   'timezones_derived': ['America/New_York'],
#   'lats_derived': [35.7803977],
#   'lngs_derived': [-78.6390989],
#   'domain_derived': 'unitedhealthgroup.com',
#   'org_linkedin_slug': 'unitedhealth-group',
#   'ai_salary_currency': 'USD',
#   'ai_salary_value': None,
#   'ai_salary_min_value': 91700,
#   'ai_salary_max_value': 163700,
#   'ai_salary_unit_text': 'YEAR',
#   'ai_benefits': ['Comprehensive benefits package',
#    'Incentive programs',
#    'Recognition programs',
#    'Equity stock purchase',
#    '401k contribution',
#    'Career development opportunities'],
#   'ai_experience_level': '5-10',
#   'ai_work_arrangement': 'Remote OK',
#   'ai_work_arrangement_office_days': None,
#   'ai_remote_location': ['United States'],
#   'ai_remote_location_derived': ['United States'],
#   'ai_key_skills': ['Data Engineering',
#    'Databricks',
#    'Spark',
#    'Python',
#    'SQL',
#    'ETL',
#    'Cloud Computing',
#    'Azure',
#    'GCP',
#    'AWS',
#    'Data Modeling',
#    'Power BI',
#    'AI-powered solutions',
#    'Semantic modeling',
#    'Data pipelines',
#    'Analytics engineering'],
#   'ai_hiring_manager_name': None,
#   'ai_hiring_manager_email_address': None,
#   'ai_core_responsibilities': 'Design, develop, and deploy AI-powered solutions and optimize complex ETL processes using Databricks to ensure high-performance data integration. Partner with business leaders to translate requirements into automated data solutions while maintaining executive-level dashboards and semantic models.',
#   'ai_requirements_summary': "Requires a bachelor's degree and 6+ years of experience in analytics or data engineering, including 5+ years of cloud experience. Candidates must have 4+ years of hands-on experience with Databricks and advanced data modeling techniques.",
#   'ai_working_hours': 40,
#   'ai_employment_type': ['FULL_TIME'],
#   'ai_job_language': 'English',
#   'ai_visa_sponsorship': False,
#   'ai_keywords': ['Data Engineering',
#    'Databricks',
#    'Spark',
#    'Python',
#    'SQL',
#    'ETL',
#    'Cloud',
#    'Azure',
#    'GCP',
#    'AWS',
#    'OCI',
#    'Data Modeling',
#    'Star Schemas',
#    'Power BI',
#    'AI',
#    'Analytics',
#    'Business Intelligence',
#    'Airflow',
#    'Azure Data Factory',
#    'Data Lineage',
#    'Large Language Models',
#    'DAX',
#    'Power Query',
#    'Semantic Modeling',
#    'Clinical Analytics',
#    'Real-time Analytics',
#    'Data Pipelines',
#    'Automation',
#    'Scalability',
#    'Healthcare'],
#   'ai_taxonomies_a': ['Data & Analytics',
#    'Technology',
#    'Software',
#    'Healthcare',
#    'Engineering'],
#   'ai_education': ['bachelor degree'],
#   'description_text': "Optum is a global organization that delivers care, aided by technology to help millions of people live healthier lives. The work you do with our team will directly improve health outcomes by connecting people with the care, pharmacy benefits, data and resources they need to feel their best. Here, you will find a culture guided by inclusion, talented peers, comprehensive benefits and career development opportunities. Come make an impact on the communities we serve as you help us advance health optimization on a global scale. Join us to start Caring. Connecting. Growing together. \nYou’ll enjoy the flexibility to telecommute* from anywhere within the U.S. as you take on some tough challenges.\nPrimary Responsibilities:\nDesign, develop, and deploy AI-powered solutions to address complex business challenges with an emphasis on the responsible use of AI\nArchitect and optimize complex ETL processes and data pipelines using Databricks (Spark, SQL, Python) or other enterprise-scale integration tools to ensure high-performance processing of large-scale datasets\nEvaluate emerging trends in ETL frameworks and AI to inform solution design and drive strategic innovation within the analytics platform\nUse enterprise-approved AI tools to automate data engineering workflows, streamline ETL maintenance, and drive continuous improvement in engineering velocity\nImplement advanced data modeling techniques, such as star schemas and incremental loads, to ensure data integrity and scalability across all ETL layers\nBuild and maintain executive-level dashboards and semantic models in Power BI, ensuring seamless data flow from backend ETL processes to end-user visualizations\nPartner with product and business leaders to translate complex business requirements into robust, automated data integration solutions\nLead technical coordination within a global delivery model, ensuring consistency and quality of ETL standards across onshore and offshore teams\nDesign, develop, and deploy AI-powered solutions to address complex business challenges with emphasis on responsible use of AI \nYou’ll be rewarded and recognized for your performance in an environment that will challenge you and give you clear directions on what it takes to succeed in your role as well as provide development for other roles you may be interested in.\n\n\nRequired Qualifications: \nBachelor's degree or equivalent experience\n6+ years of experience in analytics engineering, business intelligence, or data engineering roles delivering enterprise-scale analytics solutions\n5+ years of Cloud experience (Azure, GCP, AWS, or OCI)\n5+ years of experience in programming languages such as Python, Java, etc.\n4+ years of hands-on experience using Databricks (Spark, SQL, Python, notebooks) or other major ETL platforms to build and optimize large-scale data pipelines\n4+ years of experience in data modeling (star schemas, semantic modeling, incremental loads, large datasets) and advanced SQL\n1+ years of experience delivering AI-driven analytics or data solutions\nPreferred Qualifications:\nHealthcare industry experience, specifically in clinical or real-time analytics\nExperience with ETL orchestration tools (e.g., Airflow, Azure Data Factory) and managing data lineage in governed environments\nExperience developing AI-driven automations or integrating large language models (LLMs) into data products and ETL workflows\nExperience with Power BI, Tableau or other visualization tools, including advanced DAX, Power Query, and semantic modeling\nDemonstrated experience working in global delivery models with effective onshore-offshore collaboration\nProven ability to solve complex technical problems with a focus on data processing efficiency and system scalability\nAll Telecommuters will be required to adhere to UnitedHealth Group’s Telecommuter Policy.\nPay is based on several factors including but not limited to local labor markets, education, work experience, certifications, e ...

# %%
df=pd.DataFrame(response.json())

# %%
df
# Out:
#            id              date_posted                date_created  \
# 0  2294536084      2026-08-04T15:37:14  2026-08-04T16:19:34.051266
# 1  2294472560      2026-08-04T15:24:47  2026-08-04T15:39:56.550987
# 2  2294472561      2026-08-04T15:24:36  2026-08-04T15:39:56.594832
# 3  2294433539      2026-08-04T14:30:36  2026-08-04T15:15:55.974075
# 4  2294393006      2026-08-04T14:17:02   2026-08-04T14:51:49.39792
# 5  2294404752      2026-08-04T14:16:10   2026-08-04T15:00:46.92597
# 6  2294344847  2026-08-04T14:02:18.877  2026-08-04T14:05:55.654802
# 7  2294326420      2026-08-04T13:07:49  2026-08-04T13:54:51.457293
# 8  2294228556      2026-08-04T12:34:56  2026-08-04T12:35:02.981823
# 9  2294239758      2026-08-04T07:13:26  2026-08-04T12:44:50.175544
#
#                                                title             organization  \
# 0                      Senior Data Platform Engineer                   Gemini
# 1             Senior Data Center Facilities Engineer                   Oracle
# 2             Senior Data Center Facilities Engineer                   Oracle
# 3                            Principal Data Engineer    SMART TECH SKILLS LLC
# 4                                      Data Engineer          Software Finder
# 5                                   AI Data Engineer                     SAIC
# 6  Senior Mechanical Commissioning Engineer (Data...  Veolia Environnement SA
# 7                    Senior Salesforce Data Engineer         Cherokee Federal
# 8              Senior Data Architect / Data Engineer             Jahnel Group
# 9                               Senior Data Engineer       UnitedHealth Group
#
#                                     organization_url date_valid_through  \
# 0                                               None               None
# 1  https://eeho.fa.us2.oraclecloud.com:443/hcmUI/...               None
# 2  https://eeho.fa.us2.oraclecloud.com:443/hcmUI/...               None
# 3                        https://smarttechskills.com               None
# 4           https://softwarefinder.na.teamtailor.com               None
# 5  https://eihu.fa.us8.oraclecloud.com:443/hcmUI/...               None
# 6                                               None               None
# 7  https://ibtcjb.fa.ocs.oraclecloud.com:443/hcmU...               None
# 8                                               None               None
# 9                                               None               None
#
#                                            locations  \
# 0  [{'@type': 'Place', 'address': {'@type': 'Post...
# 1  [{'@type': 'Place', 'address': {'@type': 'Post...
# 2  [{'@type': 'Place', 'address': {'@type': 'Post...
# 3  [{'@type': 'Place', 'address': {'@type': 'Post...
# 4  [{'@type': 'Place', 'address': {'streetAddress...
# 5  [{'@type': 'Place', 'address': {'@type': 'Post...
# 6  [{'address': {'streetAddress': '1301 Bellwood ...
# 7  [{'@type': 'Place', 'address': {'@type': 'Post...
# 8  [{'@type': 'Place', 'address': {'@type': 'Post...
# 9  [{'@type': 'Place', 'address': {'@type': 'Post...
#
#                                        locations_alt location_type  ...  \
# 0  [New York, NY, United States, Miami, FL, Unite...          None  ...
# 1                                               None                ...
# 2                                               None                ...
# 3                                               None          None  ...
# 4                                               None          None  ...
# 5                                               None                ...
# 6        [1301 Bellwood Rd, Richmond, VA 23237, USA]          None  ...
# 7                                               None                ...
# 8                   [Schenectady, NY, United States]          None  ...
# 9                       [Raleigh, NC, United States]          None  ...
#
#                             ai_core_responsibilities  \
# 0  You will be responsible for the reliability, a...
# 1  The engineer will track and monitor critical d...
# 2  The engineer will track and monitor critical d...
# 3  The Principal Data Engineer will design, devel...
# 4  Design, build, and maintain scalable ETL/ELT p...
# 5  The AI Data Engineer will design, develop, and...
# 6  The Senior Mechanical Commissioning Engineer w...
# 7  The Data Engineer will build and enhance Sales...
# 8  The role involves designing and leading a comp...
# 9  Design, develop, and deploy AI-powered solutio...
#
#                              ai_requirements_summary ai_working_hours  \
# 0  The role requires at least 5 years of experien...               40
# 1  Candidates must have at least 8 years of exper...               40
# 2  Candidates must have at least 8 years of exper...               40
# 3  Candidates must have at least 7 years of exper...               40
# 4  Requires a bachelor's degree in a technical fi...               40
# 5  Candidates must have at least a bachelor's deg...               40
# 6  Candidates must possess a BSc/MSc in Mechanica...               40
# 7  Candidates must possess a bachelor's degree an...               40
# 8  Candidates must have 8+ years of experience in...               40
# 9  Requires a bachelor's degree and 6+ years of e...               40
#
#   ai_employment_type ai_job_language ai_visa_sponsorship  \
# 0        [FULL_TIME]         English               False
# 1        [FULL_TIME]         English               False
# 2        [FULL_TIME]         English               False
# 3        [FULL_TIME]         English               False
# 4        [FULL_TIME]         English               False
# 5        [FULL_TIME]         English               False
# 6        [FULL_TIME]         English               False
# 7        [FULL_TIME]         English               False
# 8        [FULL_TIME]         English               False
# 9        [FULL_TIME]         English               False
#
#                                          ai_keywords  \
# 0  [Data Platform Engineer, SRE, PostgreSQL, Amaz...
# 1  [Data Center, Infrastructure, Maintenance, SLA...
# 2  [Data Center, Infrastructure, Maintenance, SLA...
# 3  [Data Architecture, Data Modeling, Data Govern...
# 4  [Data Engineering, AWS, ETL, ELT, SQL, Python,...
# 5  [AI Data Engineer, SAIC, Fort Belvoir, Data Pi...
# 6  [Mechanical Engineering, Commissioning, Data C...
# 7  [Salesforce, Apex, Lightning Web Components, D...
# 8  [Data Architect, Data Engineer, Software Creat...
# 9  [Data Engineering, Databricks, Spark, Python, ...
#
#                                      ai_taxonomies_a  \
# 0  [Technology, Engineering, Data & Analytics, So...
# 1  [Technology, Engineering, Data & Analytics, Se...
# 2        [Technology, Engineering, Data & Analytics]
# 3  [Data & Analytics, Technology, Software, Engin...
# 4  [Technology, Data & Analytics, Software, Engin...
# 5  [Technology, Data & Analytics, Software, Gover...
# 6  [Engineering, Construction, Energy, Environmen...
# 7  [Technology, Software, Data & Analytics, Gover...
# 8  [Data & Analytics, Software, Technology, Engin...
# 9  [Data & Analytics, Technology, Software, Healt...
#
#                              ai_education  \
# 0                                    None
# 1                       [bachelor degree]
# 2                       [bachelor degree]
# 3                                    None
# 4                       [bachelor degree]
# 5  [bachelor degree, postgraduate degree]
# 6  [bachelor degree, postgraduate degree]
# 7                       [bachelor degree]
# 8                       [bachelor degree]
# 9                       [bachelor degree]
#
#                                     description_text
# 0  About the Company\nGemini is a global crypto a...
# 1  Contributes to tracking and monitoring ongoing...
# 2  Contributes to tracking and monitoring ongoing...
# 3  Location\nOnsite: Tallahassee, FL\n\nExperienc...
# 4  Job Overview\nSoftware Finder is seeking skill...
# 5  SAIC is seeking an AI Data Engineer to join ou...
# 6  Company Description\nVeolia in North America i...
# 7  Data Engineer, Senior \n\n \n\n***As required ...
# 8  Jahnel Group’s mission is to provide the absol...
# 9  Optum is a global organization that delivers c...
#
# [10 rows x 53 columns]

# %%
df.
